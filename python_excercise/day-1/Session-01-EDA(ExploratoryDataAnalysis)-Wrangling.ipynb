# %%
import numpy as np
import pandas as pd

# %%
d = {
    'product_cat': ['X', 'Y','X', 'Y', 'Z', 'Y','X'],
    'sales_Qty': [42,23,64,13,30,30,54],
    'sale_date'
    : ['2022/January/15', '2022/January/15', '2022/January/12', '2022/January/20', '2022/February/05', '2022/February/06','2022/march/12'],
    'audit_date': ['2022/March/31', '2022/March/31', '2022/March/31', '2022/March/31', '2022/March/31', '2022/March/31','2022/March/31'],
    'revenue': [1000,12000,8000,4000,18000,1000,19000]
}

# %%
df = pd.DataFrame(d)
df
# Out:
#   product_cat  sales_Qty         sale_date     audit_date  revenue
# 0           X         42   2022/January/15  2022/March/31     1000
# 1           Y         23   2022/January/15  2022/March/31    12000
# 2           X         64   2022/January/12  2022/March/31     8000
# 3           Y         13   2022/January/20  2022/March/31     4000
# 4           Z         30  2022/February/05  2022/March/31    18000
# 5           Y         30  2022/February/06  2022/March/31     1000
# 6           X         54     2022/march/12  2022/March/31    19000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   product_cat  7 non-null      object
#  1   sales_Qty    7 non-null      int64
#  2   sale_date    7 non-null      object
#  3   audit_date   7 non-null      object
#  4   revenue      7 non-null      int64
# dtypes: int64(2), object(3)
# memory usage: 412.0+ bytes

# %% [markdown]
# ## Type Casting:
# 1.`.to_datetime()` converts object to datetime

# %%
df
# Out:
#   product_cat  sales_Qty         sale_date     audit_date  revenue
# 0           X         42   2022/January/15  2022/March/31     1000
# 1           Y         23   2022/January/15  2022/March/31    12000
# 2           X         64   2022/January/12  2022/March/31     8000
# 3           Y         13   2022/January/20  2022/March/31     4000
# 4           Z         30  2022/February/05  2022/March/31    18000
# 5           Y         30  2022/February/06  2022/March/31     1000
# 6           X         54     2022/march/12  2022/March/31    19000

# %%
df.sale_date=pd.to_datetime(df.sale_date)
df['audit_date'] = pd.to_datetime(df['audit_date'])

# %%
df.sale_date
# Out:
# 0   2022-01-15
# 1   2022-01-15
# 2   2022-01-12
# 3   2022-01-20
# 4   2022-02-05
# 5   2022-02-06
# 6   2022-03-12
# Name: sale_date, dtype: datetime64[ns]

# %% [markdown]
# ## Subsetting

# %%
col1 = ['sale_date','product_cat']
df[col1]
# Out:
#    sale_date product_cat
# 0 2022-01-15           X
# 1 2022-01-15           Y
# 2 2022-01-12           X
# 3 2022-01-20           Y
# 4 2022-02-05           Z
# 5 2022-02-06           Y
# 6 2022-03-12           X

# %%
df[['sale_date','product_cat']]
# Out:
#    sale_date product_cat
# 0 2022-01-15           X
# 1 2022-01-15           Y
# 2 2022-01-12           X
# 3 2022-01-20           Y
# 4 2022-02-05           Z
# 5 2022-02-06           Y
# 6 2022-03-12           X

# %%
df
# Out:
#   product_cat  sales_Qty  sale_date audit_date  revenue
# 0           X         42 2022-01-15 2022-03-31     1000
# 1           Y         23 2022-01-15 2022-03-31    12000
# 2           X         64 2022-01-12 2022-03-31     8000
# 3           Y         13 2022-01-20 2022-03-31     4000
# 4           Z         30 2022-02-05 2022-03-31    18000
# 5           Y         30 2022-02-06 2022-03-31     1000
# 6           X         54 2022-03-12 2022-03-31    19000

# %%
df['sale_day']=df['sale_date'].dt.day
df
# Out:
#   product_cat  sales_Qty  sale_date audit_date  revenue  sale_day
# 0           X         42 2022-01-15 2022-03-31     1000        15
# 1           Y         23 2022-01-15 2022-03-31    12000        15
# 2           X         64 2022-01-12 2022-03-31     8000        12
# 3           Y         13 2022-01-20 2022-03-31     4000        20
# 4           Z         30 2022-02-05 2022-03-31    18000         5
# 5           Y         30 2022-02-06 2022-03-31     1000         6
# 6           X         54 2022-03-12 2022-03-31    19000        12

# %%
df['sale_year']=df['sale_date'].dt.year
df
# Out:
#   product_cat  sales_Qty  sale_date audit_date  revenue  sale_day  sale_year
# 0           X         42 2022-01-15 2022-03-31     1000        15       2022
# 1           Y         23 2022-01-15 2022-03-31    12000        15       2022
# 2           X         64 2022-01-12 2022-03-31     8000        12       2022
# 3           Y         13 2022-01-20 2022-03-31     4000        20       2022
# 4           Z         30 2022-02-05 2022-03-31    18000         5       2022
# 5           Y         30 2022-02-06 2022-03-31     1000         6       2022
# 6           X         54 2022-03-12 2022-03-31    19000        12       2022

# %%
df['sale_month']=df['sale_date'].dt.month
df
# Out:
#   product_cat  sales_Qty  sale_date audit_date  revenue  sale_day  sale_year  \
# 0           X         42 2022-01-15 2022-03-31     1000        15       2022
# 1           Y         23 2022-01-15 2022-03-31    12000        15       2022
# 2           X         64 2022-01-12 2022-03-31     8000        12       2022
# 3           Y         13 2022-01-20 2022-03-31     4000        20       2022
# 4           Z         30 2022-02-05 2022-03-31    18000         5       2022
# 5           Y         30 2022-02-06 2022-03-31     1000         6       2022
# 6           X         54 2022-03-12 2022-03-31    19000        12       2022
#
#    sale_month
# 0           1
# 1           1
# 2           1
# 3           1
# 4           2
# 5           2
# 6           3

# %% [markdown]
# 2022-01-15 -. 'yyyy-mm-dd'

# %%
df['sale_day_name']=df['sale_date'].dt.day_name()
df
# Out:
#   product_cat  sales_Qty  sale_date audit_date  revenue  sale_day  sale_year  \
# 0           X         42 2022-01-15 2022-03-31     1000        15       2022
# 1           Y         23 2022-01-15 2022-03-31    12000        15       2022
# 2           X         64 2022-01-12 2022-03-31     8000        12       2022
# 3           Y         13 2022-01-20 2022-03-31     4000        20       2022
# 4           Z         30 2022-02-05 2022-03-31    18000         5       2022
# 5           Y         30 2022-02-06 2022-03-31     1000         6       2022
# 6           X         54 2022-03-12 2022-03-31    19000        12       2022
#
#    sale_month sale_day_name
# 0           1      Saturday
# 1           1      Saturday
# 2           1     Wednesday
# 3           1      Thursday
# 4           2      Saturday
# 5           2        Sunday
# 6           3      Saturday

# %%
df['weekend']=df['sale_date'].dt.day_name().isin(['Saturday','Sunday'])

# %%
df
# Out:
#   product_cat  sales_Qty  sale_date audit_date  revenue  sale_day  sale_year  \
# 0           X         42 2022-01-15 2022-03-31     1000        15       2022
# 1           Y         23 2022-01-15 2022-03-31    12000        15       2022
# 2           X         64 2022-01-12 2022-03-31     8000        12       2022
# 3           Y         13 2022-01-20 2022-03-31     4000        20       2022
# 4           Z         30 2022-02-05 2022-03-31    18000         5       2022
# 5           Y         30 2022-02-06 2022-03-31     1000         6       2022
# 6           X         54 2022-03-12 2022-03-31    19000        12       2022
#
#    sale_month sale_day_name  weekend
# 0           1      Saturday     True
# 1           1      Saturday     True
# 2           1     Wednesday    False
# 3           1      Thursday    False
# 4           2      Saturday     True
# 5           2        Sunday     True
# 6           3      Saturday     True

# %%
def weekend_or_weekday(is_weekend):
    if is_weekend:
        return 'weekend'
    else:
        return 'weekday'
df['weekend_name']=df['weekend'].map(weekend_or_weekday)

# %%
df
# Out:
#   product_cat  sales_Qty  sale_date audit_date  revenue  sale_day  sale_year  \
# 0           X         42 2022-01-15 2022-03-31     1000        15       2022
# 1           Y         23 2022-01-15 2022-03-31    12000        15       2022
# 2           X         64 2022-01-12 2022-03-31     8000        12       2022
# 3           Y         13 2022-01-20 2022-03-31     4000        20       2022
# 4           Z         30 2022-02-05 2022-03-31    18000         5       2022
# 5           Y         30 2022-02-06 2022-03-31     1000         6       2022
# 6           X         54 2022-03-12 2022-03-31    19000        12       2022
#
#    sale_month sale_day_name  weekend weekend_name
# 0           1      Saturday     True      weekend
# 1           1      Saturday     True      weekend
# 2           1     Wednesday    False      weekday
# 3           1      Thursday    False      weekday
# 4           2      Saturday     True      weekend
# 5           2        Sunday     True      weekend
# 6           3      Saturday     True      weekend

# %%
df['x']=df['weekend'].map({True:'weekend',False:'weekday'})
df
# Out:
#   product_cat  sales_Qty  sale_date audit_date  revenue  sale_day  sale_year  \
# 0           X         42 2022-01-15 2022-03-31     1000        15       2022
# 1           Y         23 2022-01-15 2022-03-31    12000        15       2022
# 2           X         64 2022-01-12 2022-03-31     8000        12       2022
# 3           Y         13 2022-01-20 2022-03-31     4000        20       2022
# 4           Z         30 2022-02-05 2022-03-31    18000         5       2022
# 5           Y         30 2022-02-06 2022-03-31     1000         6       2022
# 6           X         54 2022-03-12 2022-03-31    19000        12       2022
#
#    sale_month sale_day_name  weekend weekend_name        x
# 0           1      Saturday     True      weekend  weekend
# 1           1      Saturday     True      weekend  weekend
# 2           1     Wednesday    False      weekday  weekday
# 3           1      Thursday    False      weekday  weekday
# 4           2      Saturday     True      weekend  weekend
# 5           2        Sunday     True      weekend  weekend
# 6           3      Saturday     True      weekend  weekend

# %% [markdown]
# ### Calculate total weekend revenue

# %%
weekend_revenue = df.loc[df['weekend'],'revenue'].sum()
print(weekend_revenue)
# Out:
# 51000

# %% [markdown]
# ## Filtering:

# %%
df[(df.sale_day_name == "Sunday")]
# Out:
#   product_cat  sales_Qty  sale_date audit_date  revenue  sale_day  sale_year  \
# 5           Y         30 2022-02-06 2022-03-31     1000         6       2022
#
#    sale_month sale_day_name  weekend weekend_name        x
# 5           2        Sunday     True      weekend  weekend

# %%
#Retrieve all Y and Z category products obtain the sale date
df[(df.product_cat=='Y')|(df.product_cat=='Z')]['revenue']
# Out:
# 1    12000
# 3     4000
# 4    18000
# 5     1000
# Name: revenue, dtype: int64

# %%
df[(df.product_cat=='Y') & (df.product_cat=='Z')]['revenue']
# Out:
# Series([], Name: revenue, dtype: int64)

# %%
# Retrieve the product category and revenue which has been done after 15th of the month
df[(df.sale_day>15)][['product_cat','revenue']]
# Out:
#   product_cat  revenue
# 3           Y     4000

# %%
df
# Out:
#   product_cat  sales_Qty  sale_date audit_date  revenue  sale_day  sale_year  \
# 0           X         42 2022-01-15 2022-03-31     1000        15       2022
# 1           Y         23 2022-01-15 2022-03-31    12000        15       2022
# 2           X         64 2022-01-12 2022-03-31     8000        12       2022
# 3           Y         13 2022-01-20 2022-03-31     4000        20       2022
# 4           Z         30 2022-02-05 2022-03-31    18000         5       2022
# 5           Y         30 2022-02-06 2022-03-31     1000         6       2022
# 6           X         54 2022-03-12 2022-03-31    19000        12       2022
#
#    sale_month sale_day_name  weekend weekend_name        x
# 0           1      Saturday     True      weekend  weekend
# 1           1      Saturday     True      weekend  weekend
# 2           1     Wednesday    False      weekday  weekday
# 3           1      Thursday    False      weekday  weekday
# 4           2      Saturday     True      weekend  weekend
# 5           2        Sunday     True      weekend  weekend
# 6           3      Saturday     True      weekend  weekend

# %%
weekend_revenue =df[df['weekend']== True]['revenue'].sum()
weekend_revenue
# Out:
# np.int64(51000)

# %%
df['Delta'] = df['audit_date']-df['sale_date']
df
# Out:
#   product_cat  sales_Qty  sale_date audit_date  revenue  sale_day  sale_year  \
# 0           X         42 2022-01-15 2022-03-31     1000        15       2022
# 1           Y         23 2022-01-15 2022-03-31    12000        15       2022
# 2           X         64 2022-01-12 2022-03-31     8000        12       2022
# 3           Y         13 2022-01-20 2022-03-31     4000        20       2022
# 4           Z         30 2022-02-05 2022-03-31    18000         5       2022
# 5           Y         30 2022-02-06 2022-03-31     1000         6       2022
# 6           X         54 2022-03-12 2022-03-31    19000        12       2022
#
#    sale_month sale_day_name  weekend weekend_name        x   Delta
# 0           1      Saturday     True      weekend  weekend 75 days
# 1           1      Saturday     True      weekend  weekend 75 days
# 2           1     Wednesday    False      weekday  weekday 78 days
# 3           1      Thursday    False      weekday  weekday 70 days
# 4           2      Saturday     True      weekend  weekend 54 days
# 5           2        Sunday     True      weekend  weekend 53 days
# 6           3      Saturday     True      weekend  weekend 19 days

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_cat    7 non-null      object
#  1   sales_Qty      7 non-null      int64
#  2   sale_date      7 non-null      datetime64[ns]
#  3   audit_date     7 non-null      datetime64[ns]
#  4   revenue        7 non-null      int64
#  5   sale_day       7 non-null      int32
#  6   sale_year      7 non-null      int32
#  7   sale_month     7 non-null      int32
#  8   sale_day_name  7 non-null      object
#  9   weekend        7 non-null      bool
#  10  weekend_name   7 non-null      object
#  11  x              7 non-null      object
#  12  Delta          7 non-null      timedelta64[ns]
# dtypes: bool(1), datetime64[ns](2), int32(3), int64(2), object(4), timedelta64[ns](1)
# memory usage: 727.0+ bytes

# %%
df['diff_days']=df['Delta']/np.timedelta64(1,'D')
df
# Out:
#   product_cat  sales_Qty  sale_date audit_date  revenue  sale_day  sale_year  \
# 0           X         42 2022-01-15 2022-03-31     1000        15       2022
# 1           Y         23 2022-01-15 2022-03-31    12000        15       2022
# 2           X         64 2022-01-12 2022-03-31     8000        12       2022
# 3           Y         13 2022-01-20 2022-03-31     4000        20       2022
# 4           Z         30 2022-02-05 2022-03-31    18000         5       2022
# 5           Y         30 2022-02-06 2022-03-31     1000         6       2022
# 6           X         54 2022-03-12 2022-03-31    19000        12       2022
#
#    sale_month sale_day_name  weekend weekend_name        x   Delta  diff_days
# 0           1      Saturday     True      weekend  weekend 75 days       75.0
# 1           1      Saturday     True      weekend  weekend 75 days       75.0
# 2           1     Wednesday    False      weekday  weekday 78 days       78.0
# 3           1      Thursday    False      weekday  weekday 70 days       70.0
# 4           2      Saturday     True      weekend  weekend 54 days       54.0
# 5           2        Sunday     True      weekend  weekend 53 days       53.0
# 6           3      Saturday     True      weekend  weekend 19 days       19.0

# %%
df['diff_days']=df['Delta']/pd.Timedelta(1, "d")
df
# Out:
#   product_cat  sales_Qty  sale_date audit_date  revenue  sale_day  sale_year  \
# 0           X         42 2022-01-15 2022-03-31     1000        15       2022
# 1           Y         23 2022-01-15 2022-03-31    12000        15       2022
# 2           X         64 2022-01-12 2022-03-31     8000        12       2022
# 3           Y         13 2022-01-20 2022-03-31     4000        20       2022
# 4           Z         30 2022-02-05 2022-03-31    18000         5       2022
# 5           Y         30 2022-02-06 2022-03-31     1000         6       2022
# 6           X         54 2022-03-12 2022-03-31    19000        12       2022
#
#    sale_month sale_day_name  weekend weekend_name        x   Delta  diff_days
# 0           1      Saturday     True      weekend  weekend 75 days       75.0
# 1           1      Saturday     True      weekend  weekend 75 days       75.0
# 2           1     Wednesday    False      weekday  weekday 78 days       78.0
# 3           1      Thursday    False      weekday  weekday 70 days       70.0
# 4           2      Saturday     True      weekend  weekend 54 days       54.0
# 5           2        Sunday     True      weekend  weekend 53 days       53.0
# 6           3      Saturday     True      weekend  weekend 19 days       19.0

# %%
pd.Timedelta(1, "w")
# Out:
# Timedelta('7 days 00:00:00')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_cat    7 non-null      object
#  1   sales_Qty      7 non-null      int64
#  2   sale_date      7 non-null      datetime64[ns]
#  3   audit_date     7 non-null      datetime64[ns]
#  4   revenue        7 non-null      int64
#  5   sale_day       7 non-null      int32
#  6   sale_year      7 non-null      int32
#  7   sale_month     7 non-null      int32
#  8   sale_day_name  7 non-null      object
#  9   weekend        7 non-null      bool
#  10  weekend_name   7 non-null      object
#  11  x              7 non-null      object
#  12  Delta          7 non-null      timedelta64[ns]
#  13  diff_days      7 non-null      float64
# dtypes: bool(1), datetime64[ns](2), float64(1), int32(3), int64(2), object(4), timedelta64[ns](1)
# memory usage: 783.0+ bytes

# %% [markdown]
# ## Sorting

# %%
df
# Out:
#   product_cat  sales_Qty  sale_date audit_date  revenue  sale_day  sale_year  \
# 0           X         42 2022-01-15 2022-03-31     1000        15       2022
# 1           Y         23 2022-01-15 2022-03-31    12000        15       2022
# 2           X         64 2022-01-12 2022-03-31     8000        12       2022
# 3           Y         13 2022-01-20 2022-03-31     4000        20       2022
# 4           Z         30 2022-02-05 2022-03-31    18000         5       2022
# 5           Y         30 2022-02-06 2022-03-31     1000         6       2022
# 6           X         54 2022-03-12 2022-03-31    19000        12       2022
#
#    sale_month sale_day_name  weekend weekend_name        x   Delta  diff_days
# 0           1      Saturday     True      weekend  weekend 75 days       75.0
# 1           1      Saturday     True      weekend  weekend 75 days       75.0
# 2           1     Wednesday    False      weekday  weekday 78 days       78.0
# 3           1      Thursday    False      weekday  weekday 70 days       70.0
# 4           2      Saturday     True      weekend  weekend 54 days       54.0
# 5           2        Sunday     True      weekend  weekend 53 days       53.0
# 6           3      Saturday     True      weekend  weekend 19 days       19.0

# %%
df.sort_values(by='revenue',ascending=True)
# Out:
#   product_cat  sales_Qty  sale_date audit_date  revenue  sale_day  sale_year  \
# 0           X         42 2022-01-15 2022-03-31     1000        15       2022
# 5           Y         30 2022-02-06 2022-03-31     1000         6       2022
# 3           Y         13 2022-01-20 2022-03-31     4000        20       2022
# 2           X         64 2022-01-12 2022-03-31     8000        12       2022
# 1           Y         23 2022-01-15 2022-03-31    12000        15       2022
# 4           Z         30 2022-02-05 2022-03-31    18000         5       2022
# 6           X         54 2022-03-12 2022-03-31    19000        12       2022
#
#    sale_month sale_day_name  weekend weekend_name        x   Delta  diff_days
# 0           1      Saturday     True      weekend  weekend 75 days       75.0
# 5           2        Sunday     True      weekend  weekend 53 days       53.0
# 3           1      Thursday    False      weekday  weekday 70 days       70.0
# 2           1     Wednesday    False      weekday  weekday 78 days       78.0
# 1           1      Saturday     True      weekend  weekend 75 days       75.0
# 4           2      Saturday     True      weekend  weekend 54 days       54.0
# 6           3      Saturday     True      weekend  weekend 19 days       19.0

# %%
df.sort_values(by='revenue',ascending=False)
# Out:
#   product_cat  sales_Qty  sale_date audit_date  revenue  sale_day  sale_year  \
# 6           X         54 2022-03-12 2022-03-31    19000        12       2022
# 4           Z         30 2022-02-05 2022-03-31    18000         5       2022
# 1           Y         23 2022-01-15 2022-03-31    12000        15       2022
# 2           X         64 2022-01-12 2022-03-31     8000        12       2022
# 3           Y         13 2022-01-20 2022-03-31     4000        20       2022
# 0           X         42 2022-01-15 2022-03-31     1000        15       2022
# 5           Y         30 2022-02-06 2022-03-31     1000         6       2022
#
#    sale_month sale_day_name  weekend weekend_name        x   Delta  diff_days
# 6           3      Saturday     True      weekend  weekend 19 days       19.0
# 4           2      Saturday     True      weekend  weekend 54 days       54.0
# 1           1      Saturday     True      weekend  weekend 75 days       75.0
# 2           1     Wednesday    False      weekday  weekday 78 days       78.0
# 3           1      Thursday    False      weekday  weekday 70 days       70.0
# 0           1      Saturday     True      weekend  weekend 75 days       75.0
# 5           2        Sunday     True      weekend  weekend 53 days       53.0

# %%
df[df.product_cat=='X'].sort_values(by='revenue',ascending=False)
# Out:
#   product_cat  sales_Qty  sale_date audit_date  revenue  sale_day  sale_year  \
# 6           X         54 2022-03-12 2022-03-31    19000        12       2022
# 2           X         64 2022-01-12 2022-03-31     8000        12       2022
# 0           X         42 2022-01-15 2022-03-31     1000        15       2022
#
#    sale_month sale_day_name  weekend weekend_name        x   Delta  diff_days
# 6           3      Saturday     True      weekend  weekend 19 days       19.0
# 2           1     Wednesday    False      weekday  weekday 78 days       78.0
# 0           1      Saturday     True      weekend  weekend 75 days       75.0

# %%
df.sort_values(by=['revenue','sale_day'],ascending=[True,False])
# Out:
#   product_cat  sales_Qty  sale_date audit_date  revenue  sale_day  sale_year  \
# 0           X         42 2022-01-15 2022-03-31     1000        15       2022
# 5           Y         30 2022-02-06 2022-03-31     1000         6       2022
# 3           Y         13 2022-01-20 2022-03-31     4000        20       2022
# 2           X         64 2022-01-12 2022-03-31     8000        12       2022
# 1           Y         23 2022-01-15 2022-03-31    12000        15       2022
# 4           Z         30 2022-02-05 2022-03-31    18000         5       2022
# 6           X         54 2022-03-12 2022-03-31    19000        12       2022
#
#    sale_month sale_day_name  weekend weekend_name        x   Delta  diff_days
# 0           1      Saturday     True      weekend  weekend 75 days       75.0
# 5           2        Sunday     True      weekend  weekend 53 days       53.0
# 3           1      Thursday    False      weekday  weekday 70 days       70.0
# 2           1     Wednesday    False      weekday  weekday 78 days       78.0
# 1           1      Saturday     True      weekend  weekend 75 days       75.0
# 4           2      Saturday     True      weekend  weekend 54 days       54.0
# 6           3      Saturday     True      weekend  weekend 19 days       19.0

# %%
df.sort_values(by=['revenue','sale_day'])
# Out:
#   product_cat  sales_Qty  sale_date audit_date  revenue  sale_day  sale_year  \
# 5           Y         30 2022-02-06 2022-03-31     1000         6       2022
# 0           X         42 2022-01-15 2022-03-31     1000        15       2022
# 3           Y         13 2022-01-20 2022-03-31     4000        20       2022
# 2           X         64 2022-01-12 2022-03-31     8000        12       2022
# 1           Y         23 2022-01-15 2022-03-31    12000        15       2022
# 4           Z         30 2022-02-05 2022-03-31    18000         5       2022
# 6           X         54 2022-03-12 2022-03-31    19000        12       2022
#
#    sale_month sale_day_name  weekend weekend_name        x   Delta  diff_days
# 5           2        Sunday     True      weekend  weekend 53 days       53.0
# 0           1      Saturday     True      weekend  weekend 75 days       75.0
# 3           1      Thursday    False      weekday  weekday 70 days       70.0
# 2           1     Wednesday    False      weekday  weekday 78 days       78.0
# 1           1      Saturday     True      weekend  weekend 75 days       75.0
# 4           2      Saturday     True      weekend  weekend 54 days       54.0
# 6           3      Saturday     True      weekend  weekend 19 days       19.0

# %% [markdown]
# ## Groupby
#
# identifying a prb statement to appley groupby
# reqyuirement:
# 1. cat column
# 2. aggregation(sum,max,min) based on column

# %% [markdown]
# ## Sum of revenue by prd_cat

# %%
df.groupby(['product_cat'])['revenue'].sum()
# Out:
# product_cat
# X    28000
# Y    17000
# Z    18000
# Name: revenue, dtype: int64

# %%
#max of diff_days and sum of revenue by prd_cat
df.groupby(['product_cat']).agg({"revenue":'sum','diff_days':'max'}).rename(columns={'revenue':'sum_revenue'})
# Out:
#              sum_revenue  diff_days
# product_cat
# X                  28000       78.0
# Y                  17000       75.0
# Z                  18000       54.0

# %%
d = {
    'product_cat': ['X', 'Y','X', 'Y', 'Z', 'Y','X'],
    'sales_Qty': [42,23,64,13,30,30,54],
    'sale_date': ['2022/January/15', '2022/January/15', '2022/January/12', '03-03-2022', '2022/February/05', '2022/February/06','2022/march/12'],
    'audit_date': ['2022/March/31', '2022/March/31', '2022/March/31', '2022/March/31', '2022/March/31', '2022/March/31','2022/March/31'],
    'revenue': [1000,12000,8000,4000,18000,1000,19000]
}

# %%
df1 = pd.DataFrame(d)
df1
# Out:
#   product_cat  sales_Qty         sale_date     audit_date  revenue
# 0           X         42   2022/January/15  2022/March/31     1000
# 1           Y         23   2022/January/15  2022/March/31    12000
# 2           X         64   2022/January/12  2022/March/31     8000
# 3           Y         13        03-03-2022  2022/March/31     4000
# 4           Z         30  2022/February/05  2022/March/31    18000
# 5           Y         30  2022/February/06  2022/March/31     1000
# 6           X         54     2022/march/12  2022/March/31    19000

# %%
# Convert 'sale_date' and 'audit_date' to datetime
df1['sale_date'] = pd.to_datetime(df['sale_date'])
df1['audit_date'] = pd.to_datetime(df['audit_date'])

# %%
df1
# Out:
#   product_cat  sales_Qty  sale_date audit_date  revenue
# 0           X         42 2022-01-15 2022-03-31     1000
# 1           Y         23 2022-01-15 2022-03-31    12000
# 2           X         64 2022-01-12 2022-03-31     8000
# 3           Y         13 2022-01-20 2022-03-31     4000
# 4           Z         30 2022-02-05 2022-03-31    18000
# 5           Y         30 2022-02-06 2022-03-31     1000
# 6           X         54 2022-03-12 2022-03-31    19000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   product_cat  7 non-null      object
#  1   sales_Qty    7 non-null      int64
#  2   sale_date    7 non-null      datetime64[ns]
#  3   audit_date   7 non-null      datetime64[ns]
#  4   revenue      7 non-null      int64
# dtypes: datetime64[ns](2), int64(2), object(1)
# memory usage: 412.0+ bytes

# %%
! pip install pandas
! pip updagrad
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# ERROR: unknown command "updagrad"
