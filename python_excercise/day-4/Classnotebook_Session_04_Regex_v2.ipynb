# %% [markdown]
# +91-1234567888
# - string methods - split() - Drawbacks-These specified specific direction(symbol,pre,post)

# %% [markdown]
# ***Session Duration : 2hrs 45min:***
# # **Introduction**
# ## Whats is regular expressions?
#
# - A regular expression is a group of characters or symbols which is used to find a specific pattern in a text.
#
# **'or'**
#
# - A regular expression is a pattern that is matched against a subject string from left to right. Regular expressions are used to replace text within a string, validate forms, extract a substring from a string based on a pattern match, and so much more. The term "regular expression" is a mouthful, so you will usually find the term abbreviated to "regex" or "regexp".
#
#
# ## **Regular Expressions (Regex) Overview**
#
# ### **Purpose of Regular Expressions**
# Regular expressions are widely used for:
# 1. **Extracting insights from text** → `findall()`
# 2. **Cleaning text** → `sub()`
# 3. **Validating input formats** → Ensuring correctness of data, such as emails, phone numbers, and IDs.
# 4. **Manipulating and transforming strings** → Reformatting text based on patterns.
#
#
# A **regular expression** is a pattern used to search for specific text patterns in a string. It allows us to:
# - **Search** for patterns
# - **Replace** text
# - **Validate** form inputs
# - **Extract** information from text
#
#
#
# - Rotates around-string/text data
# - Not for Int/float
#
# ### **Basic Meta Characters in Regular Expressions**
# | Meta Character | Description | Example |
# |---------------|-------------|---------|
# | `.`  | Matches any single character except newline | `c.t` → matches `cat`, `cot`, `cut` |
# | `*`  | Matches **zero or more** occurrences of the previous character | `ca*t` → matches `ct`, `cat`, `caaat` |
# | `+`  | Matches **one or more** occurrences of the previous character | `ca+t` → matches `cat`, `caaat` but not `ct` |
# | `^`  | Matches at the **start** of a string and negation| `^Hello` → matches `"Hello world"`, but not `"world Hello"` |
# | `$`  | Matches at the **end** of a string | `world$` → matches `"Hello world"`, but not `"world Hello"` |
# | `[]` | Matches **one** of the set of characters within brackets | `[aeiou]` → matches any vowel in a word |
# | `[a-z]` | Matches **one** lowercase letter from `a` to `z` | `[a-z]` → matches `a, b, c, ..., z` |
# | `[^abc]` | Matches **any character except** `a`, `b`, or `c` | `[^abc]` → matches `d, e, f, ...` |
# | `{n,m}` | Matches at **least `n` but not more than `m`** occurrences of the preceding character | `a{2,4}` → matches `aa`, `aaa`, `aaaa` |
#
# ---
#
#
# ---

# %% [markdown]
# # **Regular Expressions (Regex) Overview**
#
# - They are used for **text processing tasks** such as searching, replacing, extracting, and validating text.
# - Regular expressions provide a powerful and efficient way to manipulate strings, making them a valuable tool in various programming languages and applications.
#
#
# ## **Applications of Regular Expressions**
# Regular expressions are widely used in:
# - **Data Validation:** Ensuring proper formats for email addresses, phone numbers, and IDs.
# - **Web Scraping:** Extracting specific data from web pages.
# - **Log File Analysis:** Searching for patterns in logs for debugging and monitoring.
# - **Text Processing:** Automated text replacement, formatting, and parsing in programming.
# - **Form Input Validation:** Ensuring correctness of user inputs in web forms.
#
# ## Practice:
# 1. https://www.regexone.com/
# 2. https://regexr.com/
# 3. https://regex101.com/

# %%
# python - module-> file with functions
import re

# %%
text = 'Around 2500 patients are a taking_part in clinical trails #Coronavirus'

# %%
# finad all lower case letter sequence
out1 = re.findall('[a-z]+',text)
out1
# Out:
# ['round',
#  'patients',
#  'are',
#  'a',
#  'taking',
#  'part',
#  'in',
#  'clinical',
#  'trails',
#  'oronavirus']

# %%
# lower and upper case(all case) squence
re.findall('[A-Za-z]+',text)
# Out:
# ['Around',
#  'patients',
#  'are',
#  'a',
#  'taking',
#  'part',
#  'in',
#  'clinical',
#  'trails',
#  'Coronavirus']

# %%
re.findall('[A-Za-z]*',text)
# Out:
# ['Around',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'patients',
#  '',
#  'are',
#  '',
#  'a',
#  '',
#  'taking',
#  '',
#  'part',
#  '',
#  'in',
#  '',
#  'clinical',
#  '',
#  'trails',
#  '',
#  '',
#  'Coronavirus',
#  '']

# %%
# sequence non-alph characters
re.findall('[^a-zA-Z]+',text)
# Out:
# [' 2500 ', ' ', ' ', ' ', '_', ' ', ' ', ' ', ' #']

# %% [markdown]
# ### **Extended Meta Characters in Regular Expressions**
# | Meta Character | Description | Example |
# |---------------|-------------|---------|
# | `\d`  | Matches **any digit** (0-9) | `\d+` → matches `123`, `456` |
# | `\D`  | Matches **any non-digit** character | `\D+` → matches `Hello`, `abc` |
# | `\w`  | Matches **any word character** (letters, digits, underscore) | `\w+` → matches `word`, `test_123` |
# | `\W`  | Matches **any non-word** character | `\W+` → matches `@#$%` |
# | `\s`  | Matches **any whitespace** character (spaces, tabs, newlines) | `\s+` → matches spaces in `"Hello  World"` |
# | `\S`  | Matches **any non-whitespace** character | `\S+` → matches `"Hello"` in `"Hello  World"` |
# | `()`  | **Grouping** for extraction | `(ab)+` → matches `ababab` |
# | `{}`  | **Frequency specifier** for exact match count | `a{3}` → matches `aaa` but not `aa` |
# | `?`  | Makes a pattern **non-greedy** (matches the shortest possible string) | `ab+?` matches only `ab` in `abbbb` |

# %%
text
# Out:
# 'Around 2500 patients are a taking_part in clinical trails #Coronavirus'

# %%
# to find all words including number and underscore
re.findall('\w+',text)
# Out:
# ['Around',
#  '2500',
#  'patients',
#  'are',
#  'a',
#  'taking_part',
#  'in',
#  'clinical',
#  'trails',
#  'Coronavirus']

# %%
text1 = "The film Titanic was released in year 98 and was a hit till the year 2000 \n5000 was the cost of the mobile\ni bargained it to "
print(text1)
# Out:
# The film Titanic was released in year 98 and was a hit till the year 2000
# 5000 was the cost of the mobile
# i bargained it to

# %%
# find all the numbers across multple lines without condsidering line breaking
re.findall('\d+',text1)
# Out:
# ['98', '2000', '5000']

# %%
# get only numbers in 1st line of the sentence ->['98','2000']

# %%
text1.splitlines()
# Out:
# ['The film Titanic was released in year 98 and was a hit till the year 2000 ',
#  '5000 was the cost of the mobile',
#  'i bargained it to ']

# %%
for line in text1.splitlines():
    pattern = re.findall('\d+',line)
    print(pattern)

# %% [markdown]
# for line in text1.splitlines(): -> line:
#     pattern = re.findall('\d+',line)
#     print(pattern)

# %%
Loop1:
for line in text1.splitlines(): -> line='The film Titanic was released in year 98 and was a hit till the year 2000 '
    pattern = re.findall('\d+',line)
    print(pattern) -> ['98','2000']

Loop2:
for line in text1.splitlines(): '5000 was the cost of the mobile'
    pattern = re.findall('\d+',line)
    print(pattern) -> ['5000']

Loop3:
for line in text1.splitlines():  'i bargained it to '
    pattern = re.findall('\d+',line)
    print(pattern) ->[]
Loops ->['98','2000','5000']

# %% [markdown]
# ### get only numbers in any line of the sentence

# %%
patterns=[]
for line in text1.splitlines():
    pattern = re.findall('\d+',line)
    patterns.append(pattern)
print(patterns[2])
# Out:
# []

# %%
text1
# Out:
# 'The film Titanic was released in year 98 and was a hit till the year 2000 \n5000 was the cost of the mobile\ni bargained it to '

# %%
# extraxt only numbers that are between 2 and 4 digits
for line in text1.splitlines():
    pattern = re.findall('\d{2,6}',line)
    if len(pattern)>0:
        print(pattern)
# Out:
# ['98', '2000']
# ['5000']

# %% [markdown]
# # Cleaning of text using `re.sub()`

# %%
text3='Around 2,500 patients are a taking-part in clinical trails #Coronavirus.'

# %%
# replace all non-words characters with space
re.sub('[^\w]',' ',text3)
# Out:
# 'Around 2 500 patients are a taking part in clinical trails  Coronavirus '

# %%
re.sub('[\W]',' ',text3)
# Out:
# 'Around 2 500 patients are a taking part in clinical trails  Coronavirus '

# %%
# Removes all punctuation (@, !, ', ., $, %, ?, _).
re.sub('[^\w\s]','',text3)
# Out:
# 'Around 2500 patients are a takingpart in clinical trails Coronavirus'

# %%
text4 = "film ABC  @ was ? produced %  in , year $ 1994  .  'by'   Mr_X"

# %%
#Removing special characters with nothing
re.sub("[@,'?.$%_]",'',text4) #\s{}
# Out:
# 'film ABC   was  produced   in  year  1994    by   MrX'

# %%
#Removing special characters with nothing
re.sub('[^a-zA-Z0-9 ]','',text4)
# Out:
# 'film ABC   was  produced   in  year  1994    by   MrX'

# %%
# replace non-words char and empy string
re.sub('[\W]\s{1,3}','',text4)
# re.sub('[\W\s]',' ',text4)
# Out:
# "film ABCwas produced in year 1994'byMr_X"

# %%
# remove mutiple space with single space
re.sub('\s+',' ',text4)
# Out:
# "film ABC @ was ? produced % in , year $ 1994 . 'by' Mr_X"

# %% [markdown]
# # Cleaning of nuakri.com(datascience jobs) dataset

# %%
import pandas as pd
path = 'https://raw.githubusercontent.com/punitkmryh/Practice-Datasets/refs/heads/main/datascience_jobs.csv'
jobs = pd.read_csv(path)
jobs.head()
# Out:
#                                        title  \
# 0                               Data Science
# 1       Analyst / Sr. Analyst (data Science)
# 2                    ETL Lead & Data Science
# 3                  Specialist - Data Science
# 4  Group Manager - Data Science - Python/nlp
#
#                                   location experience  \
# 0                                   Mumbai    2-4 yrs
# 1                                  Gurgaon    5-8 yrs
# 2  Chennai, Bengaluru, Mumbai, Pune, Noida   7-10 yrs
# 3            Delhi NCR, Bengaluru, Gurgaon   7-12 yrs
# 4                                Bengaluru   6-11 yrs
#
#                                               skills  \
# 0  Algorithms, Machine Learning, Python, Java, Da...
# 1  predictive modeling, predictive analytics, mac...
# 2  SQL, Data Analysis, Text Mining, SAS, R, Stati...
# 3  Specialist - Data Science, Data Science, data ...
# 4  machine learning, text mining, r, nlp, data sc...
#
#                                 company                            salary  \
# 0             Netcore Solutions Pvt Ltd        2,00,000 - 7,00,000 P.A.
# 1                 Cvent India Pvt. Ltd.       5,00,000 - 10,00,000 P.A.
# 2  COMPUTER POWER GROUP PRIVATE LIMITED      10,00,000 - 15,00,000 P.A.
# 3     Brainsearch Consulting Pvt Ltd.Â                     Not disclosed
# 4                            Staffio HR                    Not disclosed
#
#                                          description posted_date
# 0  At least 2 year of experience in data engineer...   1 day ago
# 1  Strong experience on providing predictive mode...       Today
# 2  Industry experience in building and operationa...   1 day ago
# 3  - Experience with one or more data science pro...   1 day ago
# 4  - This is a Team management role  - Skill set ...   1 day ago

# %%
jobs.shape
# Out:
# (4000, 8)

# %%
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        4000 non-null   object
#  1   location     4000 non-null   object
#  2   experience   3977 non-null   object
#  3   skills       3955 non-null   object
#  4   company      4000 non-null   object
#  5   salary       4000 non-null   object
#  6   description  1631 non-null   object
#  7   posted_date  4000 non-null   object
# dtypes: object(8)
# memory usage: 250.1+ KB

# %%
# task : from salary column, extract min and max saalry into different columns,
# if salary is ND, make it na value

# %%
salary = "2,00,000 - 7,00,000 P.A."
salary = salary.replace(',','')
salary
# Out:
# '200000 - 700000 P.A.'

# %% [markdown]
# 200000 - 700000 P.A.
#
# `() - () P.A. `

# %%
min_sal = re.findall('([0-9]+) - [0-9]+ P.A.',salary)
min_sal
# Out:
# ['200000']

# %%
max_sal = re.findall('[0-9]+ - ([0-9]+) P.A.',salary)
max_sal
# Out:
# ['700000']

# %% [markdown]
# df.apply(get_sala_min/get_sal_max)
# - apply - applies the function(udf) to each row in df

# %%
jobs['salary'].head(10)
# Out:
# 0          2,00,000 - 7,00,000 P.A.
# 1         5,00,000 - 10,00,000 P.A.
# 2        10,00,000 - 15,00,000 P.A.
# 3                      Not disclosed
# 4                      Not disclosed
# 5          2,00,000 - 4,25,000 P.A.
# 6          4,00,000 - 8,00,000 P.A.
# 7                      Not disclosed
# 8                      Not disclosed
# 9                      Not disclosed
# Name: salary, dtype: object

# %%
def get_sala_min(row):
    row = row.replace(',','') # 200000 - 700000 P.A.
    pattern = '([0-9]+) - [0-9]+ P.A.'
    salary = re.findall(pattern, row) # 20000
    if len(salary):
        return salary[0]
    else:
        return None

# %%
jobs['min_salary'] = jobs['salary'].apply(get_sala_min)

# %%
jobs[['salary','min_salary']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   salary      4000 non-null   object
#  1   min_salary  478 non-null    object
# dtypes: object(2)
# memory usage: 62.6+ KB

# %%
jobs['min_salary'] = pd.to_numeric(jobs['min_salary'], errors='coerce')
jobs['min_salary'].head(10)
# Out:
# 0     200000.0
# 1     500000.0
# 2    1000000.0
# 3          NaN
# 4          NaN
# 5     200000.0
# 6     400000.0
# 7          NaN
# 8          NaN
# 9          NaN
# Name: min_salary, dtype: float64

# %%
def get_sala_max(row):
    row = row.replace(',','')
    pattern = '[0-9]+ - ([0-9]+) P.A.'
    salary = re.findall(pattern, row)
    if len(salary):
        return salary[0]
    else:
        return None

# %%
jobs['max_salary'] = jobs['salary'].apply(get_sala_max)

# %%
jobs['max_salary'] = pd.to_numeric(jobs['max_salary'], errors='coerce')
jobs['min_salary'].head(10)
# Out:
# 0     200000.0
# 1     500000.0
# 2    1000000.0
# 3          NaN
# 4          NaN
# 5     200000.0
# 6     400000.0
# 7          NaN
# 8          NaN
# 9          NaN
# Name: min_salary, dtype: float64

# %%
jobs.head()
# Out:
#                                        title  \
# 0                               Data Science
# 1       Analyst / Sr. Analyst (data Science)
# 2                    ETL Lead & Data Science
# 3                  Specialist - Data Science
# 4  Group Manager - Data Science - Python/nlp
#
#                                   location experience  \
# 0                                   Mumbai    2-4 yrs
# 1                                  Gurgaon    5-8 yrs
# 2  Chennai, Bengaluru, Mumbai, Pune, Noida   7-10 yrs
# 3            Delhi NCR, Bengaluru, Gurgaon   7-12 yrs
# 4                                Bengaluru   6-11 yrs
#
#                                               skills  \
# 0  Algorithms, Machine Learning, Python, Java, Da...
# 1  predictive modeling, predictive analytics, mac...
# 2  SQL, Data Analysis, Text Mining, SAS, R, Stati...
# 3  Specialist - Data Science, Data Science, data ...
# 4  machine learning, text mining, r, nlp, data sc...
#
#                                 company                            salary  \
# 0             Netcore Solutions Pvt Ltd        2,00,000 - 7,00,000 P.A.
# 1                 Cvent India Pvt. Ltd.       5,00,000 - 10,00,000 P.A.
# 2  COMPUTER POWER GROUP PRIVATE LIMITED      10,00,000 - 15,00,000 P.A.
# 3     Brainsearch Consulting Pvt Ltd.Â                     Not disclosed
# 4                            Staffio HR                    Not disclosed
#
#                                          description posted_date  min_salary  \
# 0  At least 2 year of experience in data engineer...   1 day ago    200000.0
# 1  Strong experience on providing predictive mode...       Today    500000.0
# 2  Industry experience in building and operationa...   1 day ago   1000000.0
# 3  - Experience with one or more data science pro...   1 day ago         NaN
# 4  - This is a Team management role  - Skill set ...   1 day ago         NaN
#
#    max_salary
# 0    700000.0
# 1   1000000.0
# 2   1500000.0
# 3         NaN
# 4         NaN

# %%
jobs['Avg_salary'] = (jobs['min_salary']+jobs['max_salary'])/2
jobs['Avg_salary'].head()
# Out:
# 0     450000.0
# 1     750000.0
# 2    1250000.0
# 3          NaN
# 4          NaN
# Name: Avg_salary, dtype: float64

# %%
jobs.head()
# Out:
#                                        title  \
# 0                               Data Science
# 1       Analyst / Sr. Analyst (data Science)
# 2                    ETL Lead & Data Science
# 3                  Specialist - Data Science
# 4  Group Manager - Data Science - Python/nlp
#
#                                   location experience  \
# 0                                   Mumbai    2-4 yrs
# 1                                  Gurgaon    5-8 yrs
# 2  Chennai, Bengaluru, Mumbai, Pune, Noida   7-10 yrs
# 3            Delhi NCR, Bengaluru, Gurgaon   7-12 yrs
# 4                                Bengaluru   6-11 yrs
#
#                                               skills  \
# 0  Algorithms, Machine Learning, Python, Java, Da...
# 1  predictive modeling, predictive analytics, mac...
# 2  SQL, Data Analysis, Text Mining, SAS, R, Stati...
# 3  Specialist - Data Science, Data Science, data ...
# 4  machine learning, text mining, r, nlp, data sc...
#
#                                 company                            salary  \
# 0             Netcore Solutions Pvt Ltd        2,00,000 - 7,00,000 P.A.
# 1                 Cvent India Pvt. Ltd.       5,00,000 - 10,00,000 P.A.
# 2  COMPUTER POWER GROUP PRIVATE LIMITED      10,00,000 - 15,00,000 P.A.
# 3     Brainsearch Consulting Pvt Ltd.Â                     Not disclosed
# 4                            Staffio HR                    Not disclosed
#
#                                          description posted_date  min_salary  \
# 0  At least 2 year of experience in data engineer...   1 day ago    200000.0
# 1  Strong experience on providing predictive mode...       Today    500000.0
# 2  Industry experience in building and operationa...   1 day ago   1000000.0
# 3  - Experience with one or more data science pro...   1 day ago         NaN
# 4  - This is a Team management role  - Skill set ...   1 day ago         NaN
#
#    max_salary  Avg_salary
# 0    700000.0    450000.0
# 1   1000000.0    750000.0
# 2   1500000.0   1250000.0
# 3         NaN         NaN
# 4         NaN         NaN

# %% [markdown]
# # Extrract hastag from tweets

# %%
path2='https://raw.githubusercontent.com/punitkmryh/Practice-Datasets/refs/heads/main/tweets_donald_trump.csv'
tweets = pd.read_csv(path2)
tweets.head()
# Out:
#        created_at language   likes  retweets  \
# 0  6/17/2020 3:27       en  123212     18568
# 1  6/17/2020 2:45      und       0      7942
# 2  6/17/2020 2:38       en       0     23815
# 3  6/17/2020 2:37       en       0      6781
# 4  6/17/2020 2:31       en   56840     14231
#
#                                                 text
# 0  96% Approval Rating in the Republican Party. T...
# 1  RT @TONYxTWO: @thejtlewis @JoeBiden https://t....
# 2  RT @thejtlewis: â€œTrump isnâ€™t going to acce...
# 3  RT @thejtlewis: With the utmost respect, I tha...
# 4  A GREAT woman. Her son is looking down from he...

# %%
text5 = 'Around 2,500 patients are taking part in clinical trails #Coronavirus'
print(text)
print(re.findall('#\w+', text))

# %%
all_hastags=[]
for row in tweets['text']:
    row_hastags = re.findall('#\w+',row)
    all_hastags.extend(row_hastags)
print(all_hastags)
# Out:
# ['#ArmyBdaâ', '#HappyBirthdayTrump', '#GoArmy', '#USMA2020', '#WithVisionWeLead', '#JUSTIâ', '#BarelyThereBiden', '#MAGA', '#NHSEN', '#2A', '#NH01', '#2A', '#MAGA', '#WGDP', '#MAGA', '#AMERICAFirst', '#jobsreport', '#JobsReport', '#PPPworks', '#Democrats', '#FoxNews', '#MAGA', '#1']

# %% [markdown]
# Extend vs Append
# - append: single elment to end liust
# -  extend : element to end of list
#
#     - Multi-elemt adding - Extend
#     - Single-elet addding - append

# %%
all_hastags
# Out:
# ['#ArmyBdaâ',
#  '#HappyBirthdayTrump',
#  '#GoArmy',
#  '#USMA2020',
#  '#WithVisionWeLead',
#  '#JUSTIâ',
#  '#BarelyThereBiden',
#  '#MAGA',
#  '#NHSEN',
#  '#2A',
#  '#NH01',
#  '#2A',
#  '#MAGA',
#  '#WGDP',
#  '#MAGA',
#  '#AMERICAFirst',
#  '#jobsreport',
#  '#JobsReport',
#  '#PPPworks',
#  '#Democrats',
#  '#FoxNews',
#  '#MAGA',
#  '#1']

# %%
len(all_hastags)
# Out:
# 23

# %%
pd.Series(all_hastags).value_counts()
# Out:
# #MAGA                  4
# #2A                    2
# #ArmyBdaâ              1
# #GoArmy                1
# #HappyBirthdayTrump    1
# #USMA2020              1
# #WithVisionWeLead      1
# #BarelyThereBiden      1
# #JUSTIâ                1
# #NHSEN                 1
# #NH01                  1
# #WGDP                  1
# #AMERICAFirst          1
# #jobsreport            1
# #JobsReport            1
# #PPPworks              1
# #Democrats             1
# #FoxNews               1
# #1                     1
# Name: count, dtype: int64
